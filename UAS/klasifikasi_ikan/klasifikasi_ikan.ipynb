# %% [markdown]
# ## Hubungkan ke Google Drive

# %%
# Jalankan sel ini untuk menghubungkan notebook dengan Google Drive Anda.
import os
from google.colab import drive

print("Menghubungkan ke Google Drive...")
try:
    drive.mount('/content/drive')
    print("Google Drive berhasil terhubung.")
except Exception as e:
    print(f"Gagal menghubungkan Google Drive: {e}")
# Out:
# Menghubungkan ke Google Drive...
# Mounted at /content/drive
# Google Drive berhasil terhubung.

# %% [markdown]
# ## Ekstrak File ZIP dari Drive

# %%
import os

# --- Silakan Ganti Bagian Ini ---
# 1. Ganti dengan path LENGKAP ke file .zip Anda di Google Drive.
PATH_TO_ZIP_FILE = "/content/drive/MyDrive/FishImgDataset.zip"

# 2. Tentukan di mana Anda ingin mengekstraknya di Colab (biasanya /content/ sudah cukup).
DESTINATION_DIR = "/content/"
# --- Batas Modifikasi ---

# Mengekstrak file .zip
if os.path.exists(PATH_TO_ZIP_FILE):
    print(f"\nMengekstrak {os.path.basename(PATH_TO_ZIP_FILE)}...")
    # !unzip -q "{PATH_TO_ZIP_FILE}" -d "{DESTINATION_DIR}"
    print("Ekstraksi selesai.")
else:
    print(f"!!! Peringatan: File ZIP di '{PATH_TO_ZIP_FILE}' tidak ditemukan.")
    print("!!! Pastikan path sudah benar.")
# Out:
# Mengekstrak FishImgDataset.zip...
# Ekstraksi selesai.

# %% [markdown]
# ## Pemuatan Data, Pelatihan, dan Evaluasi Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, RandomFlip, RandomRotation, RandomZoom, RandomContrast, Rescaling
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# --- Langkah 1: Pengaturan Path dan Pemuatan Data ---
print("\n--- Memulai Pengaturan Path dan Pemuatan Data ---")

# PERBAIKAN: Path sekarang mengarah ke folder hasil ekstraksi di Colab, bukan di Drive.
# Ini akan membuat proses pemuatan data jauh lebih cepat.
# Ganti 'FishImgDataset' jika nama folder utama di dalam file zip Anda berbeda.
base_dataset_path = '/content/FishImgDataset'

TRAIN_DIR = os.path.join(base_dataset_path, 'train')
TEST_DIR = os.path.join(base_dataset_path, 'test')
VAL_DIR = os.path.join(base_dataset_path, 'val')

# Memeriksa apakah path benar-benar ada
if not os.path.exists(base_dataset_path):
    print(f"!!! PERINGATAN: Path dasar '{base_dataset_path}' tidak ditemukan setelah ekstraksi.")
    print("!!! Pastikan nama folder di variabel 'base_dataset_path' sudah sesuai dengan nama folder di dalam .zip Anda.")
else:
    print(f"Path folder training: {TRAIN_DIR}")
    print(f"Path folder testing: {TEST_DIR}")
    print(f"Path folder validation: {VAL_DIR}")


    # Parameter
    IMG_SIZE = (128, 128)
    BATCH_SIZE = 32
    EPOCHS = 25 # Anda bisa menaikkan ini jika hasilnya belum maksimal, misal: 50

    # Fungsi untuk memuat data dari direktori
    def load_data(directory, subset_name):
        print(f"Memuat data dari: {directory}")
        try:
            dataset = tf.keras.utils.image_dataset_from_directory(
                directory,
                label_mode='categorical', # Menggunakan 'categorical' untuk one-hot encoding
                image_size=IMG_SIZE,
                batch_size=BATCH_SIZE,
                shuffle=(subset_name == 'training') # Hanya shuffle data training
            )
            return dataset
        except Exception as e:
            print(f"Gagal memuat data dari {directory}. Error: {e}")
            print("Pastikan struktur folder benar: train, test, dan val berisi subfolder nama-nama ikan.")
            return None

    train_dataset = load_data(TRAIN_DIR, "training")
    val_dataset = load_data(VAL_DIR, "validation")
    test_dataset = load_data(TEST_DIR, "testing")

    # Hentikan jika salah satu dataset gagal dimuat
    if not all([train_dataset, val_dataset, test_dataset]):
        print("\nEksekusi dihentikan karena satu atau lebih dataset gagal dimuat.")
    else:
        class_names = train_dataset.class_names
        NUM_CLASSES = len(class_names)
        print(f"\nDataset berhasil dimuat. Ditemukan {NUM_CLASSES} kelas.")

        # --- Langkah 2: Augmentasi Data & Preprocessing ---
        print("\n--- Menyiapkan Augmentasi dan Preprocessing Data ---")

        data_augmentation = Sequential([
            RandomFlip("horizontal"),
            RandomRotation(0.2),
            RandomZoom(0.2),
            RandomContrast(0.2),
        ], name="data_augmentation")

        AUTOTUNE = tf.data.AUTOTUNE
        def preprocess_dataset(dataset, is_training=False):
            ds = dataset.map(lambda x, y: (Rescaling(1./255)(x), y), num_parallel_calls=AUTOTUNE)
            if is_training:
                ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
            return ds.prefetch(buffer_size=AUTOTUNE)

        train_ds = preprocess_dataset(train_dataset, is_training=True)
        val_ds = preprocess_dataset(val_dataset)
        test_ds = preprocess_dataset(test_dataset)
        print("Preprocessing selesai.")

        # --- Langkah 3: Membangun Model CNN ---
        print("\n--- Membangun Arsitektur Model CNN ---")

        model = Sequential([
            Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
            Conv2D(32, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2)),
            Conv2D(128, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2)),
            Conv2D(256, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2)),
            Flatten(),
            Dense(512, activation='relu'),
            Dropout(0.5),
            Dense(NUM_CLASSES, activation='softmax')
        ], name="Fish_Classifier")

        model.compile(
            optimizer=Adam(learning_rate=0.0005),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        model.summary()

        # --- Langkah 4: Melatih Model ---
        print("\n--- Memulai Pelatihan Model ---")
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        history = model.fit(
            train_ds,
            epochs=EPOCHS,
            validation_data=val_ds,
            callbacks=[early_stopping],
            verbose=1
        )
        print("Pelatihan selesai.")

        # --- Langkah 5: Evaluasi Model ---
        print("\n--- Memulai Evaluasi Model pada Data Tes ---")
        loss, accuracy = model.evaluate(test_ds)
        print(f'Test Accuracy: {accuracy:.4f}')
        print(f'Test Loss: {loss:.4f}')

        print("\nMembuat prediksi pada data tes...")
        y_pred_proba = model.predict(test_ds)
        y_pred = np.argmax(y_pred_proba, axis=1)
        y_true = []
        for images, labels in test_ds:
            y_true.extend(np.argmax(labels.numpy(), axis=1))
        y_true = np.array(y_true)

        print("\nLaporan Klasifikasi (Classification Report):")
        labels_for_report = np.arange(len(class_names))
        print(classification_report(y_true, y_pred, target_names=class_names, labels=labels_for_report, zero_division=0))

        print("\nMembuat Visualisasi Confusion Matrix...")
        cm = confusion_matrix(y_true, y_pred, labels=labels_for_report)
        plt.figure(figsize=(12, 10))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
        plt.title('Confusion Matrix', fontsize=16)
        plt.ylabel('Kelas Aktual (Actual Class)', fontsize=12)
        plt.xlabel('Kelas Prediksi (Predicted Class)', fontsize=12)
        plt.xticks(rotation=45, ha='right')
        plt.yticks(rotation=0)
        plt.tight_layout()
        plt.show()

        print("\nMembuat Visualisasi Grafik Akurasi dan Loss...")
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']
        epochs_range = range(len(acc))

        plt.figure(figsize=(14, 6))
        plt.subplot(1, 2, 1)
        plt.plot(epochs_range, acc, label='Training Accuracy')
        plt.plot(epochs_range, val_acc, label='Validation Accuracy')
        plt.legend(loc='lower right')
        plt.title('Training and Validation Accuracy')

        plt.subplot(1, 2, 2)
        plt.plot(epochs_range, loss, label='Training Loss')
        plt.plot(epochs_range, val_loss, label='Validation Loss')
        plt.legend(loc='upper right')
        plt.title('Training and Validation Loss')
        plt.show()
# Out:
# --- Memulai Pengaturan Path dan Pemuatan Data ---
# Path folder training: /content/FishImgDataset/train
# Path folder testing: /content/FishImgDataset/test
# Path folder validation: /content/FishImgDataset/val
# Memuat data dari: /content/FishImgDataset/train
# Found 8819 files belonging to 31 classes.
# Memuat data dari: /content/FishImgDataset/val
# Found 2751 files belonging to 31 classes.
# Memuat data dari: /content/FishImgDataset/test
# Found 1761 files belonging to 31 classes.
#
# Dataset berhasil dimuat. Ditemukan 31 kelas.
#
# --- Menyiapkan Augmentasi dan Preprocessing Data ---
# Preprocessing selesai.
#
# --- Membangun Arsitektur Model CNN ---
# Model: "Fish_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 31)             │        15,903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,793,439 (33.54 MB)
#  Trainable params: 8,793,439 (33.54 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Memulai Pelatihan Model ---
# Epoch 1/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 75s 242ms/step - accuracy: 0.1475 - loss: 3.2654 - val_accuracy: 0.2508 - val_loss: 2.7939
# Epoch 2/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 72s 231ms/step - accuracy: 0.2540 - loss: 2.7353 - val_accuracy: 0.3181 - val_loss: 2.4106
# Epoch 3/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 82s 230ms/step - accuracy: 0.3007 - loss: 2.4644 - val_accuracy: 0.3613 - val_loss: 2.2295
# Epoch 4/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 82s 229ms/step - accuracy: 0.3468 - loss: 2.2806 - val_accuracy: 0.3911 - val_loss: 2.0691
# Epoch 5/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 60s 216ms/step - accuracy: 0.3940 - loss: 2.1179 - val_accuracy: 0.3969 - val_loss: 2.1305
# Epoch 6/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 61s 220ms/step - accuracy: 0.4130 - loss: 2.0531 - val_accuracy: 0.4747 - val_loss: 1.8065
# Epoch 7/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 82s 220ms/step - accuracy: 0.4381 - loss: 1.9222 - val_accuracy: 0.4733 - val_loss: 1.8071
# Epoch 8/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - accuracy: 0.4775 - loss: 1.8186 - val_accuracy: 0.4646 - val_loss: 1.9458
# Epoch 9/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 62s 225ms/step - accuracy: 0.4966 - loss: 1.7311 - val_accuracy: 0.5205 - val_loss: 1.6747
# Epoch 10/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 64s 231ms/step - accuracy: 0.5144 - loss: 1.6639 - val_accuracy: 0.5631 - val_loss: 1.4867
# Epoch 11/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 64s 230ms/step - accuracy: 0.5251 - loss: 1.5892 - val_accuracy: 0.5569 - val_loss: 1.4898
# Epoch 12/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 61s 219ms/step - accuracy: 0.5530 - loss: 1.5269 - val_accuracy: 0.5889 - val_loss: 1.3973
# Epoch 13/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 59s 214ms/step - accuracy: 0.5666 - loss: 1.4764 - val_accuracy: 0.5943 - val_loss: 1.4002
# Epoch 14/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 59s 215ms/step - accuracy: 0.5784 - loss: 1.4344 - val_accuracy: 0.5558 - val_loss: 1.4988
# Epoch 15/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 61s 221ms/step - accuracy: 0.5985 - loss: 1.3791 - val_accuracy: 0.6154 - val_loss: 1.3055
# Epoch 16/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 60s 217ms/step - accuracy: 0.5883 - loss: 1.3545 - val_accuracy: 0.5613 - val_loss: 1.5395
# Epoch 17/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - accuracy: 0.6129 - loss: 1.2786 - val_accuracy: 0.6685 - val_loss: 1.1236
# Epoch 18/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 86s 230ms/step - accuracy: 0.6214 - loss: 1.2623 - val_accuracy: 0.5874 - val_loss: 1.4746
# Epoch 19/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 63s 227ms/step - accuracy: 0.6311 - loss: 1.2264 - val_accuracy: 0.6361 - val_loss: 1.2367
# Epoch 20/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 61s 222ms/step - accuracy: 0.6511 - loss: 1.1674 - val_accuracy: 0.6343 - val_loss: 1.2487
# Epoch 21/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 60s 216ms/step - accuracy: 0.6565 - loss: 1.1303 - val_accuracy: 0.6369 - val_loss: 1.1953
# Epoch 22/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 60s 215ms/step - accuracy: 0.6634 - loss: 1.1074 - val_accuracy: 0.6867 - val_loss: 1.0630
# Epoch 23/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 86s 231ms/step - accuracy: 0.6739 - loss: 1.0689 - val_accuracy: 0.6267 - val_loss: 1.3087
# Epoch 24/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 64s 231ms/step - accuracy: 0.6749 - loss: 1.0748 - val_accuracy: 0.6798 - val_loss: 1.1101
# Epoch 25/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 61s 221ms/step - accuracy: 0.6908 - loss: 1.0369 - val_accuracy: 0.7096 - val_loss: 0.9740
# Pelatihan selesai.
#
# --- Memulai Evaluasi Model pada Data Tes ---
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.6639 - loss: 1.1158
# Test Accuracy: 0.6979
# Test Loss: 1.0209
#
# Membuat prediksi pada data tes...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step
#
# Laporan Klasifikasi (Classification Report):
#                        precision    recall  f1-score   support
#
#                Bangus       0.53      0.26      0.35        34
#         Big Head Carp       0.95      0.44      0.60        43
#    Black Spotted Barb       0.86      0.62      0.72        40
#               Catfish       0.66      0.63      0.64        62
#        Climbing Perch       0.55      0.53      0.54        30
#  Fourfinger Threadfin       0.83      0.63      0.72        38
#        Freshwater Eel       0.62      0.71      0.66        55
#        Glass Perchlet       0.83      0.83      0.83        77
#                  Goby       0.72      0.59      0.65       124
#             Gold Fish       0.98      1.00      0.99        41
#               Gourami       0.91      0.94      0.92        63
#            Grass Carp       0.82      0.93      0.87       238
#  Green Spotted Puffer       0.94      0.77      0.85        22
#           Indian Carp       0.86      0.79      0.82        53
#   Indo-Pacific Tarpon       0.47      0.41      0.44        39
#         Jaguar Gapote       0.87      0.89      0.88        44
#          Janitor Fish       0.56      0.78      0.65        58
#             Knifefish       0.86      0.83      0.84        65
# Long-Snouted Pipefish       0.87      0.75      0.80        52
#         Mosquito Fish       0.69      0.69      0.69        51
#               Mudfish       0.24      0.18      0.20        34
#                Mullet       0.50      0.29      0.37        38
#             Pangasius       0.96      0.61      0.74        38
#                 Perch       0.91      0.67      0.77        60
#             Scat Fish       0.86      0.91      0.88        33
#           Silver Barb       0.32      0.78      0.45        64
#           Silver Carp       1.00      0.92      0.96        48
#          Silver Perch       0.43      0.46      0.44        57
#             Snakehead       0.61      0.40      0.49        47
#            Tenpounder       0.47      0.61      0.53        56
#               Tilapia       0.52      0.51      0.51        57
#
#              accuracy                           0.70      1761
#             macro avg       0.72      0.66      0.67      1761
#          weighted avg       0.72      0.70      0.70      1761
#
#
# Membuat Visualisasi Confusion Matrix...
# Membuat Visualisasi Grafik Akurasi dan Loss...
